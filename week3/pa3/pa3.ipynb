# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ans
#
# ```C
# # include <stdio.h>
# int main()
# {
#     int a=1,b=1,c=1;
#     int x;
#     a+=b+=c;//a=2,b=2,c=1
#     x=-a*b/-c*b;//x=-2*2/-1*2=4
#     printf("a=%d,b=%d,c=%d,x=%d",a,b,c,x);
#     return 0
# }
# ```
